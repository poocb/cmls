# %% [markdown]
# # Certified Machine Learing Specialist (CMLS) Project
# _**Supervised Learning with Gradient Boosted Trees: A Binary Prediction Problem With Unbalanced Classes**_
#
# ---
#
# ---
#
# ## Contents
#
# 1. [Background](#Background)
# 1. [Preparation](#Preparation)
# 1. [Data](#Data)
#     1. [Exploration](#Exploration)
#     1. [Data Cleaning](#Data-Cleaning)
# 1. [Training](#Training)
# 1. [Hosting](#Hosting)
# 1. [Evaluation](#Evaluation)
#
#
# ---
#
# ## Background
# This notebook presents an example problem to predict for Credit Card Fraud Detection with Amazon SageMaker XGBoost.  The steps include:
#
# * Preparing your Amazon SageMaker notebook
# * Downloading data from the internet into Amazon SageMaker
# * Investigating and transforming the data so that it can be fed to Amazon SageMaker algorithms
# * Estimating a model using the Gradient Boosting algorithm
# * Evaluating the effectiveness of the model
# * Setting the model up to make on-going predictions
#
# ---
#
# ## Preparation
#
# _This notebook was created and tested on an ml.m4.xlarge notebook instance._
#
# Let's start by specifying:
#
# - The S3 bucket and prefix that you want to use for training and model data.  This should be within the same region as the Notebook Instance, training, and hosting.
# - The IAM role arn used to give training and hosting access to your data. See the documentation for how to create these.  Note, if more than one role is required for notebook instances, training, and/or hosting, please replace the boto regexp with a the appropriate full IAM role arn string(s).

# %%
bucket = 'cmlsproject'
prefix = 'sagemaker/projects'
 
# Define IAM role
import boto3
import re
from sagemaker import get_execution_role

role = get_execution_role()

# %% [markdown]
# Now let's bring in the Python libraries that we'll use throughout the analysis

# %%
import numpy as np                                # For matrix operations and numerical processing
import pandas as pd                               # For munging tabular data
import matplotlib.pyplot as plt                   # For charts and visualizations
from IPython.display import Image                 # For displaying images in the notebook
from IPython.display import display               # For displaying outputs in the notebook
from time import gmtime, strftime                 # For labeling SageMaker models, endpoints, etc.
import sys                                        # For writing outputs to notebook
import math                                       # For ceiling function
import json                                       # For parsing hosting outputs
import os                                         # For manipulating filepath names
import sagemaker                                  # Amazon SageMaker's Python SDK provides many helper functions
from sagemaker.predictor import csv_serializer    # Converts strings for HTTP POST requests on inference

# %% [markdown]
# ---
#
# ## Data
# Let's run below cell to download the dataset from my S3 storage, it's a [Credit Card Fraud Dataset](https://www.kaggle.com/mlg-ulb/creditcardfraud/home) duplicated copy from kaggle.

# %%
# !wget https://s3-ap-southeast-1.amazonaws.com/poocb-machine-learning/creditcard-dataset/creditcardfraud.zip
# !unzip -o creditcardfraud.zip
# Out:
# --2019-04-30 08:58:13--  https://s3-ap-southeast-1.amazonaws.com/poocb-machine-learning/creditcard-dataset/creditcardfraud.zip
# Resolving s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)... 52.219.40.21
# Connecting to s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)|52.219.40.21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155632 (66M) [application/zip]
# Saving to: ‘creditcardfraud.zip’
#
# creditcardfraud.zip 100%[===================>]  65.95M  69.2MB/s    in 1.0s
#
# 2019-04-30 08:58:14 (69.2 MB/s) - ‘creditcardfraud.zip’ saved [69155632/69155632]
#
# Archive:  creditcardfraud.zip
#   inflating: creditcard.csv

# %% [markdown]
# Now lets read this into a Pandas data frame and take a look.

# %%
data = pd.read_csv('./creditcard.csv', sep=',')
pd.set_option('display.max_columns', 500)     # Make sure we can see all of the columns
pd.set_option('display.max_rows', 20)         # Keep the output on one page
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# 284804  0.001396  0.232045  0.578229 -0.037501  0.640134  0.265745 -0.087371
# 284805  0.127434  0.265245  0.800049 -0.163298  0.123205 -0.569159  0.546668
# 284806  0.382948  0.261057  0.643078  0.376777  0.008797 -0.473649 -0.818267
#
#              V27       V28  Amount  Class
# 0       0.133558 -0.021053  149.62      0
# 1      -0.008983  0.014724    2.69      0
# 2      -0.055353 -0.059752  378.66      0
# 3       0.062723  0.061458  123.50      0
# 4       0.219422  0.215153   69.99      0
# 5       0.253844  0.081080    3.67      0
# 6       0.034507  0.005168    4.99      0
# 7      -1.206921 -1.085339   40.80      0
# 8       0.011747  0.142404   93.20      0
# 9       0.246219  0.083076    3.68      0
# ...          ...       ...     ...    ...
# 284797  0.131507  0.081265    5.49      0
# 284798  0.181205  0.215243   24.05      0
# 284799  0.454379  0.130308   79.99      0
# 284800 -0.080826 -0.075071    2.68      0
# 284801  0.217940  0.068803    2.69      0
# 284802  0.943651  0.823731    0.77      0
# 284803  0.068472 -0.053527   24.79      0
# 284804  0.004455 -0.026561   67.88      0
# 284805  0.108821  0.104533   10.00      0
# 284806 -0.002415  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# Let's talk about the data.  At a high level, we can see:
#
# * We have a little over 284K credit card transaction records, and 31 features for each transaction.
#
# _**Specifics on each of the features:**_
#
# *Anonymized features for confidentiality:*
# * `V1 till V28`: principle components been transformed with PCA
#
# *Non Anonymized features:*
# * `Time`:  Number of seconds(numeric) elapsed between this transaction and the first transaction in the dataset
# * `Amount`: Transaction Amount(numeric)
#
# *Target variable:*
# * `class`: Is the transaction a fraud? 1 for fraudulent, 0 otherwise.

# %% [markdown]
# ### Exploration
# Let's start exploring the data.  First, let's understand how target variable are distributed.

# %%
data['Class'].value_counts(normalize=True)
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %% [markdown]
# Notice that:
#
# * Only 0.002% of the values for our target variable `Class` are "1", so little transaction are fraud. The sample data is highly unbalanced, which are expected because fraud action is act on purpose that would be smaller percentage compare to others valid transactions.
#
# Next, since most features are anonymized, let's move on to transformation.

# %% [markdown]
# ### Data Cleaning
#
# Cleaning up data is part of nearly every machine learning project.  Since the given data already been transformed with PCA, we would just look for any missing value first.

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# As there is no missing value, we would proceed to determine whether certain features will add value in our case. From the given data, we will drop the Time feature which should not help to improve prediction of fraudulent.

# %%
model_data = data.drop(['Time',], axis=1)

# %% [markdown]
# Next, we'll divide data into 3 groups.  The model will be trained on 70% of data, evaluated 20% of data, and 10% as our testing dataset.

# %%
train_data, validation_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.7 * len(model_data)), int(0.9 * len(model_data))])   # Randomly sort the data then split out first 70%, second 20%, and last 10%

# %% [markdown]
# Amazon SageMaker's XGBoost container expects data in the libSVM or CSV data format.  For this example, we'll stick to CSV.  Note that the first column must be the target variable and the CSV should not include headers.  Also, notice that although repetitive it's easiest to do this after the train|validation|test split rather than before.  This avoids any misalignment issues due to random reordering.

# %%
pd.concat([train_data['Class'], train_data.drop(['Class'], axis=1)], axis=1).to_csv('train.csv', index=False, header=False)
pd.concat([validation_data['Class'], validation_data.drop(['Class'], axis=1)], axis=1).to_csv('validation.csv', index=False, header=False)

# %% [markdown]
# Moving on, let's create bucket to S3.

# %%
s3 = boto3.resource('s3')
my_region = boto3.session.Session().region_name # set the region of the instance
print('region set to:', my_region)
args = dict(Bucket = bucket)
args['CreateBucketConfiguration'] = dict(LocationConstraint = my_region)
try:
    if  my_region == 'us-east-1':
      s3.create_bucket(Bucket=bucket)
    else: 
      s3.create_bucket(**args)
    print('S3 bucket created successfully')
except Exception as e:
    print('S3 error: ',e)
# Out:
# region set to: ap-southeast-1
# S3 bucket created successfully

# %% [markdown]
# Now we'll copy the file to S3 for Amazon SageMaker's managed training to pickup.

# %%
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('validation.csv')

# %% [markdown]
# ---
#
# ## Training
# `xgboost` is an extremely popular, open-source package for gradient boosted trees.  It is computationally powerful, fully featured, and has been successfully used in many machine learning competitions.  Let's start with a simple `xgboost` model, trained using Amazon SageMaker's managed, distributed training framework.
#
# First we'll need to specify the ECR container location for Amazon SageMaker's implementation of XGBoost.

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'xgboost')

# %% [markdown]
# Then, because we're training with the CSV file format, we'll create `s3_input`s that our training function can use as a pointer to the files in S3, which also specify that the content type is CSV.

# %%
s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='csv')

# %% [markdown]
# First we'll need to specify training parameters to the estimator.  This includes:
# 1. The `xgboost` algorithm container
# 1. The IAM role to use
# 1. Training instance type and count
# 1. S3 location for output data
# 1. Algorithm hyperparameters
#
# And then a `.fit()` function which specifies:
# 1. S3 location for output data.  In this case we have both a training and validation set which are passed in.

# %%
sess = sagemaker.Session()

xgb = sagemaker.estimator.Estimator(container,
                                    role, 
                                    train_instance_count=1, 
                                    train_instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=sess)
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        num_round=100)

xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# INFO:sagemaker:Creating training-job with name: xgboost-2019-04-30-09-01-10-465
# 2019-04-30 09:01:10 Starting - Starting the training job...
# 2019-04-30 09:01:13 Starting - Launching requested ML instances......
# 2019-04-30 09:02:22 Starting - Preparing the instances for training......
# 2019-04-30 09:03:27 Downloading - Downloading input data
# 2019-04-30 09:03:27 Training - Downloading the training image..
# Arguments: train
# [2019-04-30:09:03:48:INFO] Running standalone xgboost training.
# [2019-04-30:09:03:48:INFO] File size need to be processed in the node: 131.72mb. Available memory size in the node: 8405.54mb
# [2019-04-30:09:03:48:INFO] Determined delimiter of CSV input is ','
# [09:03:48] S3DistributionType set as FullyReplicated
# [09:03:48] 199364x29 matrix with 5781556 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2019-04-30:09:03:48:INFO] Determined delimiter of CSV input is ','
# [09:03:48] S3DistributionType set as FullyReplicated
# [09:03:48] 56962x29 matrix with 1651898 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [09:03:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [0]#011train-error:0.000647#011validation-error:0.000632
# [09:03:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=4
# [1]#011train-error:0.000466#011validation-error:0.000527
# [09:03:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=4
# [2]#011train-error:0.000466#011validation-error:0.000544
# [09:03:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=4
# [3]#011train-error:0.000466#011validation-error:0.000579
# [09:03:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=4
# [4]#011train-error:0.000477#011validation-error:0.000579
# [09:03:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [5]#011train-error:0.000487#011validation-error:0.000579
# [09:03:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=4
# [6]#011train-error:0.000466#011validation-error:0.000579
# [09:03:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [7]#011train-error:0.000436#011validation-error:0.000562
# [09:03:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=4
# [8]#011train-error:0.000446#011validation-error:0.000562
# [09:03:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [9]#011train-error:0.000416#011validation-error:0.000509
# [09:03:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [10]#011train-error:0.000411#011validation-error:0.000509
# [09:03:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [11]#011train-error:0.000406#011validation-error:0.000492
# [09:03:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [12]#011train-error:0.000396#011validation-error:0.000492
# [09:03:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [13]#011train-error:0.000406#011validation-error:0.000492
# [09:03:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=4
# [14]#011train-error:0.000406#011validation-error:0.000492
# [09:03:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 10 pruned nodes, max_depth=3
# [15]#011train-error:0.000401#011validation-error:0.000492
# [09:03:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=4
# [16]#011train-error:0.000401#011validation-error:0.000492
# [09:03:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [17]#011train-error:0.000406#011validation-error:0.000492
# [09:03:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=4
# [18]#011train-error:0.000406#011validation-error:0.000474
# [09:03:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=3
# [19]#011train-error:0.000406#011validation-error:0.000509
# [09:03:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [20]#011train-error:0.000396#011validation-error:0.000527
#
# 2019-04-30 09:03:47 Training - Training image download completed. Training in progress.[09:03:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=3
# [21]#011train-error:0.000396#011validation-error:0.000492
# [09:03:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=4
# [22]#011train-error:0.000396#011validation-error:0.000492
# [09:03:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=3
# [23]#011train-error:0.000406#011validation-error:0.000492
# [09:03:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=4
# [24]#011train-error:0.000396#011validation-error:0.000439
# [09:03:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [25]#011train-error:0.000406#011validation-error:0.000456
# [09:03:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=4
# [26]#011train-error:0.000396#011validation-error:0.000439
# [09:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [27]#011train-error:0.000391#011validation-error:0.000439
# [09:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=3
# [28]#011train-error:0.000386#011validation-error:0.000456
# [09:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=3
# [29]#011train-error:0.000386#011validation-error:0.000439
# [09:04:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [30]#011train-error:0.000376#011validation-error:0.000439
# [09:04:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [31]#011train-error:0.000366#011validation-error:0.000439
# [09:04:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [32]#011train-error:0.000356#011validation-error:0.000456
# [09:04:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=4
# [33]#011train-error:0.000346#011validation-error:0.000474
# [09:04:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=4
# [34]#011train-error:0.000346#011validation-error:0.000474
# [09:04:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [35]#011train-error:0.000346#011validation-error:0.000492
# [09:04:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=4
# [36]#011train-error:0.000341#011validation-error:0.000509
# [09:04:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [37]#011train-error:0.000336#011validation-error:0.000492
# [09:04:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [38]#011train-error:0.000336#011validation-error:0.000492
# [09:04:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [39]#011train-error:0.000341#011validation-error:0.000492
# [09:04:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [40]#011train-error:0.000331#011validation-error:0.000492
# [09:04:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [41]#011train-error:0.000336#011validation-error:0.000492
# [09:04:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 10 pruned nodes, max_depth=3
# [42]#011train-error:0.000336#011validation-error:0.000509
# [09:04:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=4
# [43]#011train-error:0.000336#011validation-error:0.000474
# [09:04:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [44]#011train-error:0.000336#011validation-error:0.000492
# [09:04:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [45]#011train-error:0.000331#011validation-error:0.000474
# [09:04:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [46]#011train-error:0.000326#011validation-error:0.000492
# [09:04:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [47]#011train-error:0.000331#011validation-error:0.000492
# [09:04:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [48]#011train-error:0.000336#011validation-error:0.000492
# [09:04:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [49]#011train-error:0.000341#011validation-error:0.000474
# [09:04:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [50]#011train-error:0.000351#011validation-error:0.000492
# [09:04:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [51]#011train-error:0.000346#011validation-error:0.000492
# [09:04:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [52]#011train-error:0.000346#011validation-error:0.000492
# [09:04:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [53]#011train-error:0.000331#011validation-error:0.000492
# [09:04:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [54]#011train-error:0.000326#011validation-error:0.000509
# [09:04:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [55]#011train-error:0.000321#011validation-error:0.000509
# [09:04:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [56]#011train-error:0.000316#011validation-error:0.000509
# [09:04:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [57]#011train-error:0.000316#011validation-error:0.000509
# [09:04:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=3
# [58]#011train-error:0.000326#011validation-error:0.000492
# [09:04:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [59]#011train-error:0.000321#011validation-error:0.000492
# [09:04:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [60]#011train-error:0.000321#011validation-error:0.000456
# [09:04:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [61]#011train-error:0.000316#011validation-error:0.000474
# [09:04:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [62]#011train-error:0.000311#011validation-error:0.000439
# [09:04:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [63]#011train-error:0.000311#011validation-error:0.000474
# [09:04:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [64]#011train-error:0.000311#011validation-error:0.000474
# [09:04:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [65]#011train-error:0.000311#011validation-error:0.000474
# [09:04:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [66]#011train-error:0.000311#011validation-error:0.000456
# [09:04:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [67]#011train-error:0.000306#011validation-error:0.000456
# [09:04:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [68]#011train-error:0.000306#011validation-error:0.000456
# [09:04:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [69]#011train-error:0.000301#011validation-error:0.000439
# [09:04:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=2
# [70]#011train-error:0.000306#011validation-error:0.000439
# [09:04:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [71]#011train-error:0.000311#011validation-error:0.000439
# [09:04:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [72]#011train-error:0.000311#011validation-error:0.000439
# [09:04:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [73]#011train-error:0.000306#011validation-error:0.000421
# [09:04:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [74]#011train-error:0.000306#011validation-error:0.000404
# [09:04:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 10 pruned nodes, max_depth=3
# [75]#011train-error:0.000301#011validation-error:0.000386
# [09:04:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [76]#011train-error:0.000296#011validation-error:0.000386
# [09:04:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 6 pruned nodes, max_depth=2
# [77]#011train-error:0.000296#011validation-error:0.000386
# [09:04:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [78]#011train-error:0.000291#011validation-error:0.000386
# [09:04:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [79]#011train-error:0.000296#011validation-error:0.000404
# [09:04:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [80]#011train-error:0.000296#011validation-error:0.000404
# [09:04:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [81]#011train-error:0.000296#011validation-error:0.000404
# [09:04:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [82]#011train-error:0.000296#011validation-error:0.000386
# [09:04:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=3
# [83]#011train-error:0.000291#011validation-error:0.000421
# [09:04:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [84]#011train-error:0.000276#011validation-error:0.000421
# [09:04:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [85]#011train-error:0.000276#011validation-error:0.000421
# [09:04:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [86]#011train-error:0.000276#011validation-error:0.000404
# [09:04:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [87]#011train-error:0.000276#011validation-error:0.000404
# [09:04:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [88]#011train-error:0.000281#011validation-error:0.000404
# [09:04:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [89]#011train-error:0.000281#011validation-error:0.000404
# [09:04:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [90]#011train-error:0.000271#011validation-error:0.000421
# [09:04:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [91]#011train-error:0.000271#011validation-error:0.000421
# [09:04:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [92]#011train-error:0.000271#011validation-error:0.000439
# [09:04:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [93]#011train-error:0.000271#011validation-error:0.000421
# [09:04:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [94]#011train-error:0.000266#011validation-error:0.000421
# [09:04:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [95]#011train-error:0.000266#011validation-error:0.000421
# [09:04:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [96]#011train-error:0.000266#011validation-error:0.000421
# [09:04:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [97]#011train-error:0.000266#011validation-error:0.000421
# [09:04:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [98]#011train-error:0.000266#011validation-error:0.000421
# [09:04:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [99]#011train-error:0.000271#011validation-error:0.000421
#
# 2019-04-30 09:04:30 Uploading - Uploading generated training model
# 2019-04-30 09:04:30 Completed - Training job completed
# Billable seconds: 72

# %% [markdown]
# ---
#
# ## Hosting
# Now that we've trained the `xgboost` algorithm on our data, let's deploy a model that's hosted behind a real-time endpoint.

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1,
                           instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: xgboost-2019-04-30-09-06-52-337
# INFO:sagemaker:Creating endpoint with name xgboost-2019-04-30-09-01-10-465
# ------------------------------------------------------------------------------------------!

# %% [markdown]
# ---
#
# ## Evaluation
# Now we comparing actual to predicted values based on the 10% testing dataset created earlier on.
#
# Since the testing data is currently stored as NumPy arrays in memory of notebook instance.  To send it in an HTTP POST request, we'll serialize it as a CSV string and then decode the resulting CSV.
#
# *Note: For inference with CSV format, SageMaker XGBoost requires that the data does NOT include the target variable.*

# %%
xgb_predictor.content_type = 'text/csv'
xgb_predictor.serializer = csv_serializer

# %% [markdown]
# Now, we'll use a simple function to:
# 1. Loop over our test dataset
# 1. Split it into mini-batches of rows
# 1. Convert those mini-batches to CSV string payloads (notice, we drop the target variable from our dataset first)
# 1. Retrieve mini-batch predictions by invoking the XGBoost endpoint
# 1. Collect predictions and convert from the CSV output our model provides into a NumPy array

# %%
def predict(data, rows=500):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, xgb_predictor.predict(array).decode('utf-8')])

    return np.fromstring(predictions[1:], sep=',')

predictions = predict(test_data.drop(['Class'], axis=1).as_matrix())

# %% [markdown]
# Then we'll check our confusion matrix to see how well we predicted versus actuals.

# %%
pd.crosstab(index=test_data['Class'], columns=np.round(predictions), rownames=['actuals'], colnames=['predictions'])
# Out:
# predictions    0.0  1.0
# actuals
# 0            28424    3
# 1               12   42

# %% [markdown]
# As outcome above, over 24481 transactions, we predicted 45 are fraudulent and 42 of them did.  We also had 12 transactions that are fraudulent that we did not predict would be.

# %% [markdown]
# ### (Optional) Clean-up
#
# If you are done with this notebook, please run the cell below.  This will remove the hosted endpoint you created and avoid any charges from a stray instance being left on.

# %%
sagemaker.Session().delete_endpoint(xgb_predictor.endpoint)
